# %%
from re import M
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import regularizers
Model=Sequential()
Model.add(Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.001), input_shape=(1,)))
Model.add(Dense(128,activation="relu",kernel_regularizer=regularizers.l2(0.001)))
Model.add(Dense(1))
Model.compile(optimizer=Adam(),loss='mse')
x=np.random.random((1000,1))*100-50
y=x**2
hist=Model.fit(x,y,validation_split=0.2,epochs=4000,batch_size=256)
print(Model.predict([2,-6,36,88,100]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1504/4000
# 4/4 [==============================] - 0s 29ms/step - loss: 32.0727 - val_loss: 33.9783
# Epoch 1505/4000
# 4/4 [==============================] - 0s 27ms/step - loss: 31.8842 - val_loss: 33.7557
# Epoch 1506/4000
# 4/4 [==============================] - 0s 26ms/step - loss: 30.2960 - val_loss: 34.2005
# Epoch 1507/4000
# 4/4 [==============================] - 0s 25ms/step - loss: 31.4885 - val_loss: 36.0907
# Epoch 1508/4000
# 4/4 [==============================] - 0s 23ms/step - loss: 35.4460 - val_loss: 46.0000
# Epoch 1509/4000
# 4/4 [==============================] - 0s 28ms/step - loss: 36.0484 - val_loss: 35.8388
# Epoch 1510/4000
# 4/4 [==============================] - 0s 28ms/step - loss: 31.3464 - val_loss: 49.8424
# Epoch 1511/4000
# 4/4 [==============================] - 0s 21ms/step - loss: 35.2025 - val_loss: 48.5021
# Epoch 1512/4000
# ...

# %%
from re import M
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras import regularizers

Model=Sequential()
Model.add(Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.001), input_shape=(1,)))
Model.add(Dense(128,activation="relu",kernel_regularizer=regularizers.l2(0.001)))
Model.add(Dense(1))
Model.compile(optimizer=Adam(),loss='mse')

x = np.random.random((1000,1)) * 100 - 50
y = x ** 2
hist = Model.fit(x, y, validation_split=0.2, epochs=4000, batch_size=256)

inputs = np.array([2, -6, 36, 88, 100])
predictions = Model.predict(inputs)

for i in range(len(inputs)):
    print("Square of", inputs[i], ":", predictions[i][0])
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1504/4000
# 4/4 [==============================] - 0s 17ms/step - loss: 18.5516 - val_loss: 22.2876
# Epoch 1505/4000
# 4/4 [==============================] - 0s 17ms/step - loss: 18.8893 - val_loss: 20.2511
# Epoch 1506/4000
# 4/4 [==============================] - 0s 16ms/step - loss: 19.5147 - val_loss: 19.7986
# Epoch 1507/4000
# 4/4 [==============================] - 0s 19ms/step - loss: 17.9138 - val_loss: 24.4218
# Epoch 1508/4000
# 4/4 [==============================] - 0s 18ms/step - loss: 20.9131 - val_loss: 22.0284
# Epoch 1509/4000
# 4/4 [==============================] - 0s 19ms/step - loss: 20.7417 - val_loss: 17.7600
# Epoch 1510/4000
# 4/4 [==============================] - 0s 16ms/step - loss: 18.6780 - val_loss: 19.4201
# Epoch 1511/4000
# 4/4 [==============================] - 0s 17ms/step - loss: 18.9879 - val_loss: 19.2695
# Epoch 1512/4000
# ...
